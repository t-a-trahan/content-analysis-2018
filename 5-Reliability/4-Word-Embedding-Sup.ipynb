# %% [markdown]
# # Week 4 - Word Embeddings Supplemental
#
# This notebook contains two additional uses for word embeddings
#
# For this notebook we will be using the following packages

# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
#Make sure you update it before starting this notebook
import lucem_illud #pip install -U git+git://github.com/Computational-Content-Analysis-2018/lucem_illud.git

#All these packages need to be installed from pip
import gensim#For word2vec, etc
import requests #For downloading our datasets
import nltk #For stop words and stemmers
import numpy as np #For arrays
import pandas #Gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import seaborn #Makes the graphics look nicer
import sklearn.metrics.pairwise #For cosine similarity
import sklearn.manifold #For T-SNE
import sklearn.decomposition #For PCA
import copy

#gensim uses a couple of deprecated features
#we can't do anything about them so lets ignore them 
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning
# %matplotlib inline

import os #For looking through files
import os.path #For managing file paths
# Out:
# D:\computation\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# # The Score Function
#
# The score function is a simple calculation developed by [Matt Taddy](https://arxiv.org/pdf/1504.07295.pdf) to calculate the likelihood that a given text would have been generated by a word-embedding model by summing the inner product between each pair of the text's word vectors.
#
# Here, we explore this using a model trained with millions of resumes from the CareerBuilder website (we can't share the private resumes...but we can share a model built with them :-):

# %%
resume_model  = gensim.models.word2vec.Word2Vec.load('../data/resumeAll.model')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-feb52a0e13db> in <module>()
# ----> 1 resume_model  = gensim.models.word2vec.Word2Vec.load('../data/resumeAll.model')
#
# D:\computation\Anaconda3\lib\site-packages\gensim\models\word2vec.py in load(cls, *args, **kwargs)
#    1567     @classmethod
#    1568     def load(cls, *args, **kwargs):
# -> 1569         model = super(Word2Vec, cls).load(*args, **kwargs)
#    1570         # update older models
#    1571         if hasattr(model, 'table'):
#
# D:\computation\Anaconda3\lib\site-packages\gensim\utils.py in load(cls, fname, mmap)
#     279         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     280
# --> 281         obj = unpickle(fname)
#     282         obj._load_specials(fname, mmap, compress, subname)
#     283         logger.info("loaded %s", fname)
#
# D:\computation\Anaconda3\lib\site-packages\gensim\utils.py in unpickle(fname)
#     928 def unpickle(fname):
#     929     """Load pickled object from `fname`"""
# --> 930     with smart_open(fname, 'rb') as f:
#     931         # Because of loading from S3 load can't be used (missing readline in smart_open)
#     932         if sys.version_info > (3, 0):
#
# D:\computation\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py in smart_open(uri, mode, **kw)
#     174             encoding = kw.pop('encoding', None)
#     175             errors = kw.pop('errors', DEFAULT_ERRORS)
# --> 176             return file_smart_open(parsed_uri.uri_path, mode, encoding=encoding, errors=errors)
#     177         elif parsed_uri.scheme in ("s3", "s3n", 's3u'):
#     178             return s3_open_uri(parsed_uri, mode, **kw)
#
# D:\computation\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py in file_smart_open(fname, mode, encoding, errors)
#     669     except KeyError:
#     670         raw_mode = mode
# --> 671     raw_fobj = open(fname, raw_mode)
#     672     decompressed_fobj = compression_wrapper(raw_fobj, fname, raw_mode)
#     673     decoded_fobj = encoding_wrapper(decompressed_fobj, mode, encoding=encoding, errors=errors)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/resumeAll.model'

# %% [markdown]
# We can examine the vacabularies of this model by building a word-index map:

# %%
vocab = resume_model.index2word

# %% [markdown]
# Let's just load the sample and take a look at it. The sentences in each job description are already tokenized and normalized.

# %%
sampleDF = pandas.read_csv('../data/SampleJobAds.csv', index_col = False)
#We need to convert the last couple columns from strings to lists
sampleDF['tokenized_sents'] = sampleDF['tokenized_sents'].apply(lambda x: eval(x))
sampleDF['normalized_sents'] = sampleDF['normalized_sents'].apply(lambda x: eval(x))
sampleDF

# %% [markdown]
# Let's define a function to calculate the likelihood of each job description. The idea is borrowed from [Matt Taddy](https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/deepir.ipynb), who shows how a document can be characterized as the inner product of the distance between its words. In other words, this analysis will show which job ads are most likely to find an appropriate pool of workers in the resume bank that generated our word embedding.

# %%
def adprob(ad, model):
    sen_scores = model.score(ad, len(ad))
    ad_score = sen_scores.mean()
    return ad_score

# %% [markdown]
# Let's apply this function to every job description.

# %%
sampleDF['likelihood'] = sampleDF['normalized_sents'].apply(lambda x: adprob(x, resume_model))

# %% [markdown]
# Let's take a look at the top 5 job descriptions that have the highest likelihood.

# %%
for ad in sampleDF.sort_values(by = 'likelihood', ascending = False)['jobDescription'][:5]:
    print (ad + '\n\n')

# %% [markdown]
# Let's take a look at the bottom 5 job descriptions that have the lowest likelihood to be matched by the resumes.

# %%
for ad in sampleDF.sort_values(by = 'likelihood')['jobDescription'][:5]:
    print (ad + '\n\n')

# %% [markdown]
# We can do the same for phrases corresponding to job skills.

# %%
adprob([["python", "programming"]], resume_model)

# %%
adprob([["basic", "programming"]], resume_model)

# %% [markdown]
# Basic programming appears to be more likely in this pool of resumes than python programming.

# %% [markdown]
# We can also do some simple statistics. Unfortunately, we don't have a large sample here. Nevertheless, let's first look at the mean likelihood score of each hiring organization. Some organizations will do well to hire on CareerBuilder...while others will not.

# %%
sampleDF.groupby("hiringOrganization_organizationName")[['likelihood']].mean().sort_values('likelihood', ascending = False)

# %% [markdown]
# We can also look at the mean likelihood of each state.

# %%
sampleDF.groupby("jobLocation_address_region")[['likelihood']].mean().sort_values('likelihood', ascending = False)

# %% [markdown]
# You would increase the sample size if you want to do a more serious study.

# %% [markdown]
# ## <span style="color:red">*Exercise 1a*</span>
#
# <span style="color:red">**Do only 1a or 1b.** Construct cells immediately below this that calculate the scores for a small sample of documents from outside your corpus to identify which are *closest* to your corpus. Then calculate the scores for a few phrases or sentences to identify the ones most likely to have appeared in your corpus. Interrogate patterns associated with these document/phrase scores (e.g., which companies produced job ads most or least likely to find jobseekers in the resume corpus?) What do these patterns suggest about the boundaries of your corpus?

# %% [markdown]
# # Linguistic Change

# %% [markdown]
# Below is code that aligns the dimensions of multiple embeddings arrayed over time or some other dimension and allow identification of semantic chanage as the word vectors change their loadings for focal words. This code comes from the approach piloted at Stanford by William Hamilton, Daniel Jurafsky and Jure Lescovec [here](https://arxiv.org/pdf/1605.09096.pdf).

# %%
def calc_syn0norm(model):
    """since syn0norm is now depricated"""
    return (model.wv.syn0 / np.sqrt((model.wv.syn0 ** 2).sum(-1))[..., np.newaxis]).astype(np.float32)

def smart_procrustes_align_gensim(base_embed, other_embed, words=None):
    """Procrustes align two gensim word2vec models (to allow for comparison between same word across models).
    Code ported from HistWords <https://github.com/williamleif/histwords> by William Hamilton <wleif@stanford.edu>.
    (With help from William. Thank you!)
    First, intersect the vocabularies (see `intersection_align_gensim` documentation).
    Then do the alignment on the other_embed model.
    Replace the other_embed model's syn0 and syn0norm numpy matrices with the aligned version.
    Return other_embed.
    If `words` is set, intersect the two models' vocabulary with the vocabulary in words (see `intersection_align_gensim` documentation).
    """
    base_embed = copy.copy(base_embed)
    other_embed = copy.copy(other_embed)
    # make sure vocabulary and indices are aligned
    in_base_embed, in_other_embed = intersection_align_gensim(base_embed, other_embed, words=words)

    # get the embedding matrices
    base_vecs = calc_syn0norm(in_base_embed)
    other_vecs = calc_syn0norm(in_other_embed)

    # just a matrix dot product with numpy
    m = other_vecs.T.dot(base_vecs) 
    # SVD method from numpy
    u, _, v = np.linalg.svd(m)
    # another matrix operation
    ortho = u.dot(v) 
    # Replace original array with modified one
    # i.e. multiplying the embedding matrix (syn0norm)by "ortho"
    other_embed.wv.syn0norm = other_embed.wv.syn0 = (calc_syn0norm(other_embed)).dot(ortho)
    return other_embed
    
def intersection_align_gensim(m1,m2, words=None):
    """
    Intersect two gensim word2vec models, m1 and m2.
    Only the shared vocabulary between them is kept.
    If 'words' is set (as list or set), then the vocabulary is intersected with this list as well.
    Indices are re-organized from 0..N in order of descending frequency (=sum of counts from both m1 and m2).
    These indices correspond to the new syn0 and syn0norm objects in both gensim models:
        -- so that Row 0 of m1.syn0 will be for the same word as Row 0 of m2.syn0
        -- you can find the index of any word on the .index2word list: model.index2word.index(word) => 2
    The .vocab dictionary is also updated for each model, preserving the count but updating the index.
    """

    # Get the vocab for each model
    vocab_m1 = set(m1.wv.vocab.keys())
    vocab_m2 = set(m2.wv.vocab.keys())

    # Find the common vocabulary
    common_vocab = vocab_m1&vocab_m2
    if words: common_vocab&=set(words)

    # If no alignment necessary because vocab is identical...
    if not vocab_m1-common_vocab and not vocab_m2-common_vocab:
        return (m1,m2)

    # Otherwise sort by frequency (summed for both)
    common_vocab = list(common_vocab)
    common_vocab.sort(key=lambda w: m1.wv.vocab[w].count + m2.wv.vocab[w].count,reverse=True)

    # Then for each model...
    for m in [m1,m2]:
        # Replace old syn0norm array with new one (with common vocab)
        indices = [m.wv.vocab[w].index for w in common_vocab]
        old_arr = calc_syn0norm(m)
        new_arr = np.array([old_arr[index] for index in indices])
        m.wv.syn0norm = m.wv.syn0 = new_arr

        # Replace old vocab dictionary with new one (with common vocab)
        # and old index2word with new one
        m.index2word = common_vocab
        old_vocab = m.wv.vocab
        new_vocab = {}
        for new_index,word in enumerate(common_vocab):
            old_vocab_obj=old_vocab[word]
            new_vocab[word] = gensim.models.word2vec.Vocab(index=new_index, count=old_vocab_obj.count)
        m.wv.vocab = new_vocab

    return (m1,m2)

# %% [markdown]
# In order to explore this, let's get some data that follows a time trend. We'll look at conference proceedings from the American Society for Clinical Oncologists.

# %%
ascoDF = pandas.read_csv("../data/APSabstracts1950s.csv", index_col=0)

# %% [markdown]
# Prepare for wor2vec

# %%
ascoDF['tokenized_sents'] = ascoDF['abstract'].apply(lambda x: [nltk.word_tokenize(s) for s in nltk.sent_tokenize(x)])
ascoDF['normalized_sents'] = ascoDF['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(
# 4     The factorization method is an operational pro...
# 5     A brief account is given of Dyson's proof of t...
# 6     A systematics is given of all transitions for ...
# 7     A systematics of the -transitions of even A nu...
# 8     The available experiments on the absorption sp...
# 9     The classical theory of the dynamics of viscou...
# 10    The general formula for the angular distributi...
# 11    It is shown that for aluminum absorbers, a sin...
# 12    The Boltzmann theory treatment of electrical d...
# 13    A survey is given of the absorption of radiati...
# 14    Neutron diffraction measurements are reported ...
# 15    The saturation moment of ferromagnetic alloys ...
# 16    The chemical and magnetic structures of zinc f...
# 17    The temperature range of magnetic susceptibili...
# 18    Present theories of magnetization are based la...
# 19    Measurements of the E effect and the decrement...
# 20    A striking connection has been found between t...
# 21    This paper discusses investigations into the d...
# 22    Experimental results are reviewed for Fe, Co, ...
# 23    The paramagnetic properties (in particular the...
# 24    A brief description is given of the method use...
# 25    The molar specific heat CI of neodymium ethyl ...
# 26    Following a suggestion by A. Kastler, an attem...
# 27    Bromine, even in small quantities, is known to...
# 28    The magnet is an air core and water-cooled mas...
# 29    THIS symposium consisted of a round-table disc...
# ...                                                 ...
# 9679  The longitudinal exchange contribution to the ...
# 9680  The "elastic" photoproduction of 0 mesons in h...
# 9681  Multiple-scattering corrections to the impulse...
# 9682  Integral angular distributions of 860-Mev prot...
# 9683  The results of a preliminary nature on the - d...
# 9684  The nuclear internal momentum distributions of...
# 9685  Random Wilson cloud-chamber photographs of cad...
# 9686  The spectrum of electrons arising from the dec...
# 9687  Asymmetries have been observed in double charg...
# 9688  Asymmetries in neutron and proton production h...
# 9689  High-energy protons from the unpolarized exter...
# 9690  The K-series x-rays from the -mesonic Be, B, C...
# 9691  The yields of the L-series x-ray lines from -m...
# 9692  The photographs obtained by the Ecole Polytech...
# 9693  The characteristics of the decay process +++-+...
# 9694  A careful search is made for evidence of possi...
# 9695  The multiple production theories are discussed...
# 9696  Some theorems developed by Sachs and Austern, ...
# 9697  Some electromagnetic properties of nucleons ar...
# 9698  By a method proposed by Gell-Mann and Goldberg...
# 9699  The pseudoscalar theory in the Tamm-Dancoff ap...
# 9700  Magnetic analysis of the reaction B11(p,)Be9 a...
# 9701  The Tamm-Dancoff method is applied to the calc...
# 9702  The effective neutron-electron interaction is ...
# 9703  The dispersion relations of Kramers and Kronig...
# 9704  Chemical separation of the products resulting ...
# 9705  The generalized Kramers-Kronig dispersion rela...
# 9706  The question is asked whether the lowest order...
# 9707  An explicit formula for the scattering spin ma...
# 9708  A general method is described whereby the low-...
#
#                                         tokenized_sents  \
# 0     [[A, summarizing, account, is, given, of, the,...
# 1     [[New, tables, of, coulomb, functions, are, pr...
# 2     [[Ionization, by, electron, impact, in, diatom...
# 3     [[It, is, shown, that, the, conductivity, in, ...
# 4     [[The, factorization, method, is, an, operatio...
# 5     [[A, brief, account, is, given, of, Dyson, 's,...
# 6     [[A, systematics, is, given, of, all, transiti...
# 7     [[A, systematics, of, the, -transitions, of, e...
# 8     [[The, available, experiments, on, the, absorp...
# 9     [[The, classical, theory, of, the, dynamics, o...
# 10    [[The, general, formula, for, the, angular, di...
# 11    [[It, is, shown, that, for, aluminum, absorber...
# 12    [[The, Boltzmann, theory, treatment, of, elect...
# 13    [[A, survey, is, given, of, the, absorption, o...
# 14    [[Neutron, diffraction, measurements, are, rep...
# 15    [[The, saturation, moment, of, ferromagnetic, ...
# 16    [[The, chemical, and, magnetic, structures, of...
# 17    [[The, temperature, range, of, magnetic, susce...
# 18    [[Present, theories, of, magnetization, are, b...
# 19    [[Measurements, of, the, E, effect, and, the, ...
# 20    [[A, striking, connection, has, been, found, b...
# 21    [[This, paper, discusses, investigations, into...
# 22    [[Experimental, results, are, reviewed, for, F...
# 23    [[The, paramagnetic, properties, (, in, partic...
# 24    [[A, brief, description, is, given, of, the, m...
# 25    [[The, molar, specific, heat, CI, of, neodymiu...
# 26    [[Following, a, suggestion, by, A., Kastler, ,...
# 27    [[Bromine, ,, even, in, small, quantities, ,, ...
# 28    [[The, magnet, is, an, air, core, and, water-c...
# 29    [[THIS, symposium, consisted, of, a, round-tab...
# ...                                                 ...
# 9679  [[The, longitudinal, exchange, contribution, t...
# 9680  [[The, ``, elastic, '', photoproduction, of, 0...
# 9681  [[Multiple-scattering, corrections, to, the, i...
# 9682  [[Integral, angular, distributions, of, 860-Me...
# 9683  [[The, results, of, a, preliminary, nature, on...
# 9684  [[The, nuclear, internal, momentum, distributi...
# 9685  [[Random, Wilson, cloud-chamber, photographs, ...
# 9686  [[The, spectrum, of, electrons, arising, from,...
# 9687  [[Asymmetries, have, been, observed, in, doubl...
# 9688  [[Asymmetries, in, neutron, and, proton, produ...
# 9689  [[High-energy, protons, from, the, unpolarized...
# 9690  [[The, K-series, x-rays, from, the, -mesonic, ...
# 9691  [[The, yields, of, the, L-series, x-ray, lines...
# 9692  [[The, photographs, obtained, by, the, Ecole, ...
# 9693  [[The, characteristics, of, the, decay, proces...
# 9694  [[A, careful, search, is, made, for, evidence,...
# 9695  [[The, multiple, production, theories, are, di...
# 9696  [[Some, theorems, developed, by, Sachs, and, A...
# 9697  [[Some, electromagnetic, properties, of, nucle...
# 9698  [[By, a, method, proposed, by, Gell-Mann, and,...
# 9699  [[The, pseudoscalar, theory, in, the, Tamm-Dan...
# 9700  [[Magnetic, analysis, of, the, reaction, B11, ...
# 9701  [[The, Tamm-Dancoff, method, is, applied, to, ...
# 9702  [[The, effective, neutron-electron, interactio...
# 9703  [[The, dispersion, relations, of, Kramers, and...
# 9704  [[Chemical, separation, of, the, products, res...
# 9705  [[The, generalized, Kramers-Kronig, dispersion...
# 9706  [[The, question, is, asked, whether, the, lowe...
# 9707  [[An, explicit, formula, for, the, scattering,...
# 9708  [[A, general, method, is, described, whereby, ...
#
#                                        normalized_sents
# 0     [[summarizing, account, given, research, bariu...
# 1     [[new, tables, coulomb, functions, presented, ...
# 2     [[ionization, electron, impact, diatomic, gase...
# 3     [[shown, conductivity, ohmic, part, cuprous, o...
# 4     [[factorization, method, operational, procedur...
# 5     [[brief, account, given, dyson, proof, finiten...
# 6     [[systematics, given, transitions, odd, nuclei...
# 7     [[systematics, even, nuclei, given], [interpre...
# 8     [[available, experiments, absorption, spectra,...
# 9     [[classical, theory, dynamics, viscous, fluids...
# 10    [[general, formula, angular, distribution, col...
# 11    [[shown, aluminum, absorbers, single, equation...
# 12    [[boltzmann, theory, treatment, electrical, di...
# 13    [[survey, given, absorption, radiation, energy...
# 14    [[neutron, diffraction, measurements, reported...
# 15    [[saturation, moment, ferromagnetic, alloys, c...
# 16    [[chemical, magnetic, structures, zinc, ferrit...
# 17    [[temperature, range, magnetic, susceptibility...
# 18    [[present, theories, magnetization, based, lar...
# 19    [[measurements, e, effect, decrement, made, bo...
# 20    [[striking, connection, found, magnetic, prope...
# 21    [[paper, discusses, investigations, detailed, ...
# 22    [[experimental, results, reviewed, fe, co, ni,...
# 23    [[paramagnetic, properties, particular, resona...
# 24    [[brief, description, given, method, used, bat...
# 25    [[molar, specific, heat, ci, neodymium, ethyl,...
# 26    [[following, suggestion, kastler, attempt, mad...
# 27    [[bromine, even, small, quantities, known, alt...
# 28    [[magnet, air, core, massive, helmholtz, type,...
# 29    [[symposium, consisted, discussion, exchange, ...
# ...                                                 ...
# 9679  [[longitudinal, exchange, contribution, nuclea...
# 9680  [[elastic, photoproduction, mesons, helium, me...
# 9681  [[corrections, impulse, approximation, calcula...
# 9682  [[integral, angular, distributions, protons, s...
# 9683  [[results, preliminary, nature, decay, spectru...
# 9684  [[nuclear, internal, momentum, distributions, ...
# 9685  [[random, wilson, photographs, cadmium, molybd...
# 9686  [[spectrum, electrons, arising, decay, negativ...
# 9687  [[asymmetries, observed, double, scattering, c...
# 9688  [[asymmetries, neutron, proton, production, ob...
# 9689  [[protons, unpolarized, external, beam, carneg...
# 9690  [[b, c, n, atoms, studied], [case, measurement...
# 9691  [[yields, lines, atoms, measured, fourteen, el...
# 9692  [[photographs, obtained, ecole, polytechnique,...
# 9693  [[characteristics, decay, process, considered]...
# 9694  [[careful, search, made, evidence, possible, e...
# 9695  [[multiple, production, theories, discussed, p...
# 9696  [[theorems, developed, sachs, austern, regardi...
# 9697  [[electromagnetic, properties, nucleons, inves...
# 9698  [[method, proposed, goldberger, treatment, pro...
# 9699  [[pseudoscalar, theory, approximation, applied...
# 9700  [[magnetic, analysis, reaction, p, three, angl...
# 9701  [[method, applied, calculation, electrostatic,...
# 9702  [[effective, interaction, calculated, pseudosc...
# 9703  [[dispersion, relations, kramers, kronig, gene...
# 9704  [[chemical, separation, products, resulting, p...
# 9705  [[generalized, dispersion, relations, charged,...
# 9706  [[question, asked, whether, lowest, order, equ...
# 9707  [[explicit, formula, scattering, spin, matrix,...
# 9708  [[general, method, described, whereby, behavio...
#
# [9709 rows x 5 columns]

# %% [markdown]
# We will be creating many embeddings so we have created this function to do most of the work. It creates two collections of embeddings, one the original and one the aligned.

# %%
def compareModels(df, category, sort = True):
    """If you are using time as your category sorting is important"""
    embeddings_raw = {}
    cats = sorted(set(df[category]))
    for cat in cats:
        #This can take a while
        print("Embedding {}".format(cat), end = '\r')
        subsetDF = df[df[category] == cat]
        #You might want to change the W2V parameters
        embeddings_raw[cat] = gensim.models.word2vec.Word2Vec(subsetDF['normalized_sents'].sum())
    #These are much quicker
    embeddings_aligned = {}
    for catOuter in cats:
        embeddings_aligned[catOuter] = [embeddings_raw[catOuter]]
        for catInner in cats:
            embeddings_aligned[catOuter].append(smart_procrustes_align_gensim(embeddings_aligned[catOuter][-1], embeddings_raw[catInner]))
    return embeddings_raw, embeddings_aligned

# %% [markdown]
# Now we generate the models

# %%
rawEmbeddings, comparedEmbeddings = compareModels(ascoDF, 'copyrightYear')
# Out:
# Embedding 1959

# %% [markdown]
# We need to compare them across all permutions so we will define another function to help, we will be using 1 - cosine similarity as that gives a more intitive range of 0-2 with low values meaning little change and high meaning lots of change

# %%
def getDivergenceDF(word, embeddingsDict):
    dists = []
    cats = sorted(set(embeddingsDict.keys()))
    dists = {}
    for cat in cats:
        dists[cat] = []
        for embed in embeddingsDict[cat][1:]:
            dists[cat].append(np.abs(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cat][0][word], axis = 0),
                                                                             np.expand_dims(embed[word], axis = 0))[0,0]))
    return pandas.DataFrame(dists, index = cats)

# %% [markdown]
# Lets look at a couple words

# %%
targetWord = 'electron'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()

# %%
targetWord = 'temperature'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()

# %% [markdown]
# We can also ask which words changed the most

# %%
def findDiverence(word, embeddingsDict):
    cats = sorted(set(embeddingsDict.keys()))
    
    dists = []
    for embed in embeddingsDict[cats[0]][1:]:
        dists.append(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cats[0]][0][word], axis = 0), np.expand_dims(embed[word], axis = 0))[0,0])
    return sum(dists)

def findMostDivergent(embeddingsDict):
    words = []
    for embeds in embeddingsDict.values():
        for embed in embeds:
            words += list(embed.wv.vocab.keys())
    words = set(words)
    print("Found {} words to compare".format(len(words)))
    return sorted([(w, findDiverence(w, embeddingsDict)) for w in words], key = lambda x: x[1], reverse=True)

# %%
wordDivergences = findMostDivergent(comparedEmbeddings)
# Out:
# Found 952 words to compare

# %% [markdown]
# The most divergent words are:

# %%
wordDivergences[:10]
# Out:
# [('kev', 0.15904659032821655),
#  ('section', 0.14506125450134277),
#  ('cross', 0.14421117305755615),
#  ('performed', 0.1340177059173584),
#  ('responsible', 0.13016724586486816),
#  ('sections', 0.12666642665863037),
#  ('corrected', 0.113705575466156),
#  ('preliminary', 0.0965890884399414),
#  ('briefly', 0.09372013807296753),
#  ('seven', 0.08663636445999146)]

# %% [markdown]
# And the least

# %%
wordDivergences[-10:]
# Out:
# [('given', 0.0011153817176818848),
#  ('two', 0.0011118650436401367),
#  ('particles', 0.0010991692543029785),
#  ('number', 0.0010947585105895996),
#  ('also', 0.001047670841217041),
#  ('electrons', 0.0010377168655395508),
#  ('small', 0.0010375380516052246),
#  ('well', 0.0010368824005126953),
#  ('one', 0.0008900761604309082),
#  ('large', 0.0008698105812072754)]

# %%
targetWord = wordDivergences[0][0]

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()

# %%
targetWord = wordDivergences[-1][0]

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()

# %% [markdown]
# ## <span style="color:red">*Exercise 1b*</span>
#
# <span style="color:red">**Do only 3a or 3b.** Construct cells immediately below this that align word embeddings over time. Interrogate the spaces that result and ask which words change most of the whole period. What does this reveal about the social game underlying your space?

# %%
# load and prepare my corpus!

nyt = pandas.read_csv('D:/contentAnalysis/corporaTooLarge/nyt95.csv')

# now tokenize and normalize

nyt['tokenized_sents'] = nyt['article'].apply(lambda x: [nltk.word_tokenize(s) for s in nltk.sent_tokenize(x)])
nyt['normalized_sents'] = nyt['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(s, stopwordLst = lucem_illud.stop_words_basic) for s in x])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-70b6f566369e> in <module>()
#       5 # now tokenize and normalize
#       6
# ----> 7 nyt['tokenized_sents'] = nyt['article'].apply(lambda x: [nltk.word_tokenize(s) for s in nltk.sent_tokenize(x)])
#       8 nyt['normalized_sents'] = nyt['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(s, stopwordLst = lucem_illud.stop_words_basic) for s in x])
#
# D:\computation\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-19-70b6f566369e> in <lambda>(x)
#       5 # now tokenize and normalize
#       6
# ----> 7 nyt['tokenized_sents'] = nyt['article'].apply(lambda x: [nltk.word_tokenize(s) for s in nltk.sent_tokenize(x)])
#       8 nyt['normalized_sents'] = nyt['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(s, stopwordLst = lucem_illud.stop_words_basic) for s in x])
#
# <ipython-input-19-70b6f566369e> in <listcomp>(.0)
#       5 # now tokenize and normalize
#       6
# ----> 7 nyt['tokenized_sents'] = nyt['article'].apply(lambda x: [nltk.word_tokenize(s) for s in nltk.sent_tokenize(x)])
#       8 nyt['normalized_sents'] = nyt['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(s, stopwordLst = lucem_illud.stop_words_basic) for s in x])
#
# D:\computation\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     127     """
#     128     sentences = [text] if preserve_line else sent_tokenize(text, language)
# --> 129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# D:\computation\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in <listcomp>(.0)
#     128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
# --> 130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# KeyboardInterrupt:

# %%
display(nyt)

# %%
# to make things easier for comparison, let's strip the date down from day-month-year to just year

import re

def cleanerYear(x):
    return re.sub(r'(\D+)\s(\d{1,2})\W', '', x)

def cleanFix(x):
    return re.sub(r'[^\d+]', '', x)

nyt80s['date'] = nyt80s['date'].apply(cleanerYear)
nyt80s['date'] = nyt80s['date'].apply(cleanFix)

# %%
nyt80s['date'] = nyt80s['date'].astype(float)

# %%
print(len(nyt80s['date']))
# Out:
# 11200

# %%
nyt80s.dropna(axis = 0, inplace = True)

# %%
print(nyt80s)
# Out:
#                                                  article    date  \
# 0         '79 food production in Vietnam was only 13....  1980.0
# 1         Karleton Armstrong, convicted of '70 bombin...  1980.0
# 2         Militants holding US diplomatic personnel h...  1980.0
# 3         Militants holding US diplomatic personnel h...  1980.0
# 4         China apparently concludes that best strate...  1980.0
# 5         5 US chemical companies that produced milit...  1980.0
# 6         Phnom Penh, Cambodia, celebrates 1st annive...  1980.0
# 7         Australian Government agrees to form indepe...  1980.0
# 8         Warrant Officer Francis Anton, former Army ...  1980.0
# 9         Author Richard J Walton article on Soviet i...  1980.0
# 10        Former Vietnam war prisoner Luis Antonio Or...  1980.0
# 11        Vietnam accuses China of conducting large-s...  1980.0
# 12        Military prosecutors, in surprise move, fin...  1980.0
# 3      [[Militants, holding, US, diplomatic, personne...
# 4      [[China, apparently, concludes, that, best, st...
# 5      [[5, US, chemical, companies, that, produced, ...
# 6      [[Phnom, Penh, ,, Cambodia, ,, celebrates, 1st...
# 7      [[Australian, Government, agrees, to, form, in...
# 8      [[Warrant, Officer, Francis, Anton, ,, former,...
# 9      [[Author, Richard, J, Walton, article, on, Sov...
# 10     [[Former, Vietnam, war, prisoner, Luis, Antoni...
# 11     [[Vietnam, accuses, China, of, conducting, lar...
# 12     [[Military, prosecutors, ,, in, surprise, move...
# 13     [[Vietnam, accuses, US, and, China, of, milita...
# 14     [[Neil, Sheehan, interview, with, Tran, Ngoc, ...
# 15     [[Talat, Sait, Halman, article, on, prevalent,...
# 16     [[Yuri, Tavrovsky, letter, disputes, December,...
# 17     [[Pakistan, Pres, Mohammed, Zia, ul-Haq, ,, co...
# 18     [[China, accuses, Vietnam, of, killing, at, le...
# 19     [[Pakistani, Pres, Mohammed, Zia, ul-Haq, ,, i...
# 20     [[Prof, John, Somerville, letter, likens, US, ...
# 21     [[Article, on, history, of, Selective, Service...
# 22     [[Senate, approves, 15, %, increase, in, educa...
# 23     [[ILO, announces, membership, of, Vietnam, in,...
# 24     [[Letter, by, Kay, Camp, (, Women, 's, Interna...
# 25     [[Chinese, Foreign, Ministry, says, its, chief...
# 26     [[China, issues, document, reasserting, claim,...
# 27     [[Defense, witness, Staff, Sgt, John, E, Peter...
# 28     [[Karleton, Armstrong, is, released, on, Feder...
# 29     [[Military, judge, Major, Thomas, B, Hamilton,...
# ...                                                  ...
# 11170  [[Wanted, :, a, new, public, enemy, .], [Heigh...
# 11171  [[Out, Cold, 1988, .], [HBO, .], [$, 89.99, .]...
# 11172  [[It, is, Shanghai, in, 1927, .], [Chiang, Kai...
# 11173  [[Musical, eccentricity, is, an, attitude, tha...
# 11174  [[Twenty-five, years, ago, ,, a, young, unknow...
# 11175  [[On, April, 12, ,, 1975, ,, soon, after, Lon,...
# 11176  [[APPLAUSE, By, Carol, Muske, .], [53, pp, .],...
# 11177  [[WHERE, THE, RIVERS, RAN, BACKWARD, .], [By, ...
# 11178  [[A, plan, to, cut, chemical, weapons, in, the...
# 11179  [[A, headline, Saturday, on, an, article, abou...
# 11180  [[PENH, ,, Cambodia, ,, Sept., 24, Prime, Mini...
# 11181  [[,, N.J., ,, Sept., 21, Filled, with, the, co...
# 11182  [[The, Reader, 's, Digest, Association, Inc., ...
# 11183  [[CHI, MINH, CITY, ,, Vietnam, ,, Sept., 25, F...
# 11184  [[INTERNATIONAL, A3-1, President, Bush, told, ...
# 11185  [[The, economy, will, continue, to, grow, thro...
# 11186  [[BAI, ,, Vietnam, ,, Sept., 26, What, Vietnam...
# 11187  [[CHI, MINH, CITY, ,, Vietnam, ,, Sept., 26, T...
# 11188  [[Vice, President, Dan, Quayle, arrived, in, t...
# 11189  [[Vietnamese, troops, have, finally, left, Cam...
# 11190  [[Sometimes, ,, nations, are, compelled, to, o...
# 11187  [[chi, minh, city, vietnam, family, tran, van,...
# 11188  [[vice, president, dan, quayle, arrived, phili...
# 11189  [[vietnamese, troops, finally, left, cambodia]...
# 11190  [[sometimes, nations, compelled, opt, moral, h...
# 11191  [[nations, british, foreign, secretary, outlin...
# 11192  [[international, canada, becoming, money, drug...
# 11193  [[penh, cambodia, invasion, least, representat...
# 11194  [[nations, new, diplomatic, struggle, waged, v...
# 11195  [[arnold, johnson, member, national, leadershi...
# 11196  [[bush, administration, told, israel, intends,...
# 11197  [[nations, afghanistan, foreign, minister, tol...
# 11198  [[ferdinand, marcos, tough, debonair, came, ru...
# 11199  [[many, ways, war, vietnam, relentlessy, visua...
#
# [11200 rows x 4 columns]

# %%
def compareModels(df, category, sort = True):
    """If you are using time as your category sorting is important"""
    embeddings_raw = {}
    cats = sorted(set(df[category]))
    for cat in cats:
        #This can take a while
        print("Embedding {}".format(cat), end = '\r')
        subsetDF = df[df[category] == cat]
        #You might want to change the W2V parameters
        embeddings_raw[cat] = gensim.models.word2vec.Word2Vec(subsetDF['normalized_sents'].sum())
    #These are much quicker
    embeddings_aligned = {}
    for catOuter in cats:
        embeddings_aligned[catOuter] = [embeddings_raw[catOuter]]
        for catInner in cats:
            embeddings_aligned[catOuter].append(smart_procrustes_align_gensim(embeddings_aligned[catOuter][-1], embeddings_raw[catInner]))
    return embeddings_raw, embeddings_aligned

# %%
# I have not been able to get this code to work, much to my chagrin. 
# At first, I thought it might be the fact that my date column was type str,
# so I cleaned it up and tried to make it into type int

rawEmbeddings, comparedEmbeddings = compareModels(nyt80s, 'date')
# Out:
# Embedding inf01981252370198e+166
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-16-16d16097e3be> in <module>()
#       1 # I have not been able to
#       2
# ----> 3 rawEmbeddings, comparedEmbeddings = compareModels(nyt80s, 'date')
#
# <ipython-input-13-bec079c64a6f> in compareModels(df, category, sort)
#      14         embeddings_aligned[catOuter] = [embeddings_raw[catOuter]]
#      15         for catInner in cats:
# ---> 16             embeddings_aligned[catOuter].append(smart_procrustes_align_gensim(embeddings_aligned[catOuter][-1], embeddings_raw[catInner]))
#      17     return embeddings_raw, embeddings_aligned
#
# <ipython-input-3-ffd61de17354> in smart_procrustes_align_gensim(base_embed, other_embed, words)
#      25     m = other_vecs.T.dot(base_vecs)
#      26     # SVD method from numpy
# ---> 27     u, _, v = np.linalg.svd(m)
#      28     # another matrix operation
#      29     ortho = u.dot(v)
#
# D:\computation\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv)
#    1422     a, wrap = _makearray(a)
#    1423     _assertNoEmpty2d(a)
# -> 1424     _assertRankAtLeast2(a)
#    1425     t, result_t = _commonType(a)
#    1426
#
# D:\computation\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assertRankAtLeast2(*arrays)
#     199         if a.ndim < 2:
#     200             raise LinAlgError('%d-dimensional array given. Array must be '
# --> 201                     'at least two-dimensional' % a.ndim)
#     202
#     203 def _assertSquareness(*arrays):
#
# LinAlgError: 0-dimensional array given. Array must be at least two-dimensional

# %%
targetWord = 'vietnam'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()

# %%
targetWord = 'missing'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()

# %%
wordDivergences = findMostDivergent(comparedEmbeddings)
